# %% [markdown]
# ## B.Perez - Data Story Project
# Tuesday, September 24th 2024
#
# **Describe the dataset you selected (e.g., In general, what data does it contain?, What do the rows represent?, What do the columns represent? What pattern(s) do you notice?, etc.)**
# I chose the fast food nutrition dataset and it contained different fast food meals nutrition. The row represents a specific type of meal and the columns represent a specific type of
# nutrional fact about every meal. A pattern that I noticed was higher protein means higher
# saturated fat.
#
# **Describe why you selected this specific dataset (e.g., What piqued your interest?, In what ways does it relate to your future career?, Why does exploring this data matter?, etc.)**
# I selected this dataset because I'd like to know if fast food has good enough protein without
# saturated fats being a concern for all the gym rats. This matters because many people like to
# have a good cheat meal that benefits them. Having a cheat meal that's convenient for gym purposes is a dream
# for all the gym bros or even the casuals who want just the pros of junk food.
#
# **Describe a few specific questions that could be asked about this data (e.g., Is there a specific pattern you noticed that you are curious about?, What other context is not included in the data set that you are curious about?, etc.)**
# Does having higher protein always mean better meal in health terms? Will higher protein equal higher cholestral, if so does saturated fat increase as well
#
# **What question did you select?** Does having higher protein always mean better meal in health terms?
#
# **Make a prediction:** I don't think that higher protein will mean you're getting a good healthy meal because of other factors that make it unhealthy like cholestral or saturated fats these things are incorporated into foods like chicken when it's getting cooked or prepped.

# %%
#import all modules and packeages needed
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#load in the dataset that I want to use
nutrition = pd.read_csv('Fast Foods - fastfoods.csv')

#show the dataset
display(nutrition)

#take two entire columns(will use their data in next line)
nutrition_protein = nutrition['Protein (g)'].to_numpy()
nutrition_satfats = nutrition['Saturated Fats (g)'].to_numpy()
nutrition_cholestral = nutrition['Cholesterol (mg)'].to_numpy()
nutrition_sodium = nutrition['Sodium (mg)'].to_numpy()
nutrition_calories = nutrition['Calories'].to_numpy()


#use data to put them in a scatter plot
plt.scatter(nutrition_protein, nutrition_satfats)
#change axis names
plt.xlabel('Protein (g)')
plt.ylabel('Saturated Fats (g)')
plt.show()

#use scatter plot to compate protein with cholestral
plt.plot(nutrition_protein, nutrition_cholestral, color = 'yellow')

#change axis names
plt.xlabel('Protein (g)')
plt.ylabel('Cholestral (mg)')

#seperate healthy & unhealthy contents in data with dashed line
plt.axhline(y = 159, color = 'r', linestyle = 'dashed')  
plt.show()
plt.bar(nutrition['Protein (g)'], nutrition['Calories'], align='center', color = 'red')

plt.xlabel('Protein (g)') 
plt.ylabel('Calories')
plt.show()

# draw lineplot
sns.lineplot(x="Protein (g)", y="Sodium (mg)", data=nutrition, color = 'green')

# specifying horizontal line type 
plt.axhline(y = 500, color = 'b', linestyle = 'dashed') 
plt.show()
plt.show()
# Out:
#                                                Name     Type     Vendor  \
# 0                                       Kfc Biscuit  Biscuit        KFC
# 1              McDonalds Bacon Egg & Cheese Biscuit  Biscuit  McDonalds
# 2                         McDonalds Sausage Biscuit  Biscuit  McDonalds
# 3                McDonalds Sausage Biscuit With Egg  Biscuit  McDonalds
# 4          McDonalds Southern Style Chicken Biscuit  Biscuit  McDonalds
# ..                                              ...      ...        ...
# 455                              Waffle Whole Grain   Waffle      Other
# 456  Waffle Whole Grain From Fast Food / Restaurant   Waffle      Other
# 457                  Waffle Whole Grain From Frozen   Waffle      Other
# 458            Waffle Whole Grain Fruit From Frozen   Waffle      Other
# 459                  Waffle Whole Grain Reduced Fat   Waffle      Other
#
#      Calories  Fat (g)  Protein (g)  Carbohydrate (g)  Cholesterol (mg)  \
# ...

# %% [markdown]
# **Was your prediction confirmed?** My prediction is actually wrong because the more protein there is the lower the saturated fats are. I'm actually surprised that there are fast foods that have low saturated fats without compromising protein.
#
# **Conclusion on graph 1:** protein and saturated fats are being compared, This is a moderate positive correlation. After 15g of protein foods have less saturated fats.
#
# **Conclusion on graph 2:** protein and cholestral are being compared (after a quick research ldl cholestral is used in fast foods meals which is bad) what I noticed was any food under 159mg cholestral is good to eat, the closer to the line the more worse it gets. Anything over the line is bad for your health and could cause heart disease or strokes.
#
# **Sources I used for graph 2** [a link][1] and
# another [link][2].
# [1]"https://www.webmd.com/diet/high-cholesterol-foods#:~:text=Fast%20food%20is%20often%20fried,therefore%20be%20lower%20in%20cholesterol."e"
# [2]"https://medlineplus.gov/ldlthebadcholesterol.html"
#
#
#
# **Conclusion on graph 3:** protein and calories are being compared, most meals hover around 250 calories then again it is fast food. bulking with fast food is okay if again you don't abuse your cheat meal but you can't cut with these foods.
# **Conclusion on graph 4:** protein and sodium are being compared (after a quick research any salt level content over 500mg is bad for you and could even cause high blood pressure or increase heart diseases as well) any foods under the red dotted line is good/okay
#
# **Sources I used for graph 4** [a link][1]
# [1]: "https://health.ucdavis.edu/blog/good-food/your-guide-to-low-sodium-eating-and-how-to-lower-blood-pressure/2022/09#:~:text=Aim%20to%20avoid%20or%20limit,or%20less%20than%20the%20original."or you.
#
# **My Concluding thoughts:** you could eat anything over 15 grams of protein only draw back is the salt content (much water will be needed afterwards) but to be safe you should eat food in the range of 10g - 20g of protein your in the clear for alot of foods from many fast food companies.

# %% [markdown]
# **In what ways did this project contribute to your overall learning experience as a Computer Science major?** This project helped me learn a lot as a Com sci student in a few important ways: I got to actually build something, which made my understanding of the code much clearer and more interesting. Getting feedback from others on my work helped me see different ways on doing things and or improve my project. I better understood how these projects could help out others in the real world and change opinions or convey a point.
#
# **How did you develop this project iteratively over time?** I broke the project down into smaller tasks, This made it easier to manage progress and not feel overwhelmed. After completing each task, I tested the code as best as I could thoroughly and I continued this cycle of testing and fixing. Throughout the process, I documented my changes and decisions. This helped keep track of my progress.
#
# **What might you have done differently?** If I had more time I would've checked for a better dataset on fast food nutrition and pictured an already clear point with my graphs and even clear and showing how protein could be good for you after seeing these results.
#
# **If you were to extend your work on this project, what might your next steps be?** My next step would be to go find a better data set that breaks down certain nutritional facts like fats, cholestral etc.
